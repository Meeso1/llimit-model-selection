# %%
from datasets import load_dataset

ds = load_dataset("lmarena-ai/arena-human-preference-140k")
train = ds["train"].to_pandas()

# %%
train.head()

# %%
(train["model_a"].value_counts() + train["model_b"].value_counts()).sort_values(ascending=False)
