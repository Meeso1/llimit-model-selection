# %%
from src.utils.training_logger import load_training_log, list_training_runs, TrainingLog
from src.plotting import gb_length_prediction, dn_length_prediction, dn_embedding, response_predictive, transformer_embedding, attention_embedding_model, gradient_boosting

# %%
_ = attention_embedding_model.plot_metrics(load_training_log('gradient-boosting-scoring', timestamp=1777139846))

# %%
_ = attention_embedding_model.plot_metrics(load_training_log('gradient-boosting-scoring-chatbot-arena', timestamp=1777139252))

# %%
_ = dn_length_prediction.plot_metrics_4by2(load_training_log('dn-embedding-length-prediction', timestamp=1777075103), skip_first_n_epochs=1)

# %%
_ = dn_length_prediction.plot_metrics_4by2(load_training_log('dn-embedding-length-prediction-chatbot-arena', timestamp=1777074175), skip_first_n_epochs=1)

# %%
_ = dn_embedding.plot_metrics(load_training_log('dn-embedding-scoring', timestamp=1777154143))

# %%
_ = dn_embedding.plot_metrics(load_training_log('dn-embedding-scoring-chatbot-arena', timestamp=1777150950))

# %%
_ = gb_length_prediction.plot_metrics_4by2(load_training_log('gb-length-prediction', timestamp=1777140386))

# %%
_ = gb_length_prediction.plot_metrics_4by2(load_training_log('gb-length-prediction-chatbot-arena', timestamp=1777140662))

# %%
_ = response_predictive.plot_metrics_2x3by2(load_training_log('response-predictive-scoring', timestamp=1777159739))

# %%
_ = response_predictive.plot_metrics_2x3by2(load_training_log('response-predictive-scoring-chatbot-arena', timestamp=1777158730))

# %%
_ = transformer_embedding.plot_metrics(load_training_log('transformer-embedding-scoring', timestamp=1777163514))

# %%
_ = transformer_embedding.plot_metrics(load_training_log('transformer-embedding-scoring-chatbot-arena', timestamp=1777193088))

# %%
_ = gradient_boosting.plot_loss_accuracy(load_training_log('gradient-boosting-scoring-only-llm-embedding', timestamp=1777203179))

# %%
_ = gradient_boosting.plot_loss_accuracy(load_training_log('gradient-boosting-scoring-only-llm-embedding-chatbot-arena', timestamp=1777203216))
